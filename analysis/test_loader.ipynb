# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

from utils import load_eval_dirs, load_eval_dirs_parallel
from single_eval_logs import (
    get_multi_bar_decomposition_data,
    get_cheating_rate,
    parse_logs_with_function,
)
from plotting import create_stacked_flag_bar_plot, plot_bars_with_ci

ROOT_DIR = Path(
    "/Users/tsimur.hadeliya/code/Agent-Misalignment-from-Unreliable-Tool-Behavior"
)

# %%
per_model_evals = load_eval_dirs_parallel(
    base_dir=ROOT_DIR / "logs/spar/imp_livecodebench", exclude_model=[], max_workers=16
)
# Out:
# Loading models...: 100%|██████████| 5/5 [10:43<00:00, 128.72s/it]
